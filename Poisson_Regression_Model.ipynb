# %%
# load the data
import pandas as pd
train_data = pd.read_csv("Data/TRAIN/merged_cleaned_train_data.csv")
test_data = pd.read_csv("Data/TEST/novartis_test_data_merged_full(New).csv")

# %%
train_data = train_data.drop(columns=["Unnamed: 0"])

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93744 entries, 0 to 93743
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         93744 non-null  object
#  1   brand_name      93744 non-null  object
#  2   month           93744 non-null  object
#  3   months_postgx   93744 non-null  int64
#  4   volume          93744 non-null  float64
#  5   n_gxs           93744 non-null  int64
#  6   ther_area       93744 non-null  object
#  7   hospital_rate   90672 non-null  float64
#  8   main_package    93744 non-null  object
#  9   biological      93744 non-null  bool
#  10  small_molecule  93744 non-null  bool
# dtypes: bool(2), float64(2), int64(2), object(5)
# memory usage: 6.6+ MB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8832 entries, 0 to 8831
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         8832 non-null   object
#  1   brand_name      8832 non-null   object
#  2   month           8832 non-null   object
#  3   months_postgx   8832 non-null   int64
#  4   volume          8832 non-null   float64
#  5   n_gxs           672 non-null    float64
#  6   ther_area       8832 non-null   object
#  7   hospital_rate   8832 non-null   float64
#  8   main_package    8832 non-null   object
#  9   biological      8832 non-null   bool
#  10  small_molecule  8832 non-null   bool
# dtypes: bool(2), float64(3), int64(1), object(5)
# memory usage: 638.4+ KB

# %%
# identify input and output
X_train = train_data.drop("volume", axis=1)
X_test = test_data.drop("volume", axis=1)
y_train = train_data.volume
y_test = test_data.volume

# %%
# one hot encode
from sklearn.preprocessing import OneHotEncoder
enc_train = OneHotEncoder()
enc_train.fit(X_train)
X_train_enc = enc_train.transform(X_train)

enc_test = OneHotEncoder()
enc_test.fit(X_test)
X_test_enc = enc_test.transform(X_test)

# %%
# one hot encode 
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore')
enc.fit(X_train)
X_train_enc = enc.transform(X_train)
X_test_enc = enc.transform(X_test)

# %%
# standardise
from sklearn.preprocessing import StandardScaler
std = StandardScaler(with_mean=False)
X_train_std = std.fit_transform(X_train_enc)
X_test_std = std.fit_transform(X_test_enc)

# %%
# initialise and train the Poisson Regression model
from sklearn.linear_model import PoissonRegressor
poisson_model = PoissonRegressor()
poisson_model.fit(X_train_std, y_train)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\linear_model\_glm\glm.py:283: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# PoissonRegressor()

# %%
# Make predictions on the test set
y_pred = poisson_model.predict(X_test_std)

# %%
pred_df = pd.DataFrame(y_pred, columns=["volume"])

# %%
pred_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8832 entries, 0 to 8831
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   volume  8832 non-null   float64
# dtypes: float64(1)
# memory usage: 69.1 KB

# %%
pred_df.head(50)
# Out:
#            volume
# 0   227558.420591
# 1   217291.295814
# 2   243791.306709
# 3   223723.259185
# 4   230296.896790
# 5   229192.609588
# 6   234602.670330
# 7   218346.153932
# 8   235507.214757
# 9   252458.750032
# 10  228146.801601
# 11  255291.133420
# 12  223560.521693
# 13  216066.338548
# 14  242313.909548
# 15  223701.532450
# 16  218669.523998
# 17  218401.900991
# 18  221658.847722
# 19  211261.317821
# 20  222804.307083
# 21  229651.752881
# 22  218812.098753
# 23  239723.983788
# 24   86244.506275
# 25   73503.641543
# 26   76688.780484
# 27   67212.655822
# 28   66361.773161
# 29   69226.803350
# 30   58130.338207
# 31   54512.889545
# 32   56235.815773
# 33   50461.290403
# 34   51969.279038
# 35   58551.260600
# 36   56398.704949
# 37   54793.418188
# 38   55926.509269
# 39   57826.944959
# 40   50950.589513
# 41   57879.525936
# 42   57109.065453
# 43   54205.578753
# 44   55895.021691
# 45   50456.389888
# 46   49345.421793
# 47   55794.585364
# 48   53286.997691
# 49   53015.496385

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8832 entries, 0 to 8831
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         8832 non-null   object
#  1   brand_name      8832 non-null   object
#  2   month           8832 non-null   object
#  3   months_postgx   8832 non-null   int64
#  4   n_gxs           672 non-null    float64
#  5   ther_area       8832 non-null   object
#  6   hospital_rate   8832 non-null   float64
#  7   main_package    8832 non-null   object
#  8   biological      8832 non-null   bool
#  9   small_molecule  8832 non-null   bool
# dtypes: bool(2), float64(2), int64(1), object(5)
# memory usage: 569.4+ KB

# %%
X_test.head(50)
# Out:
#          country  brand_name month  months_postgx  n_gxs  \
# 0   COUNTRY_9891  BRAND_DB48   Oct            -24    NaN
# 1   COUNTRY_9891  BRAND_DB48   Nov            -23    NaN
# 2   COUNTRY_9891  BRAND_DB48   Dec            -22    NaN
# 3   COUNTRY_9891  BRAND_DB48   Jan            -21    NaN
# 4   COUNTRY_9891  BRAND_DB48   Feb            -20    NaN
# 5   COUNTRY_9891  BRAND_DB48   Mar            -19    NaN
# 6   COUNTRY_9891  BRAND_DB48   Apr            -18    NaN
# 7   COUNTRY_9891  BRAND_DB48   May            -17    NaN
# 8   COUNTRY_9891  BRAND_DB48   Jun            -16    NaN
# 9   COUNTRY_9891  BRAND_DB48   Jul            -15    NaN
# 10  COUNTRY_9891  BRAND_DB48   Aug            -14    NaN
# 11  COUNTRY_9891  BRAND_DB48   Sep            -13    NaN
# 12  COUNTRY_9891  BRAND_DB48   Oct            -12    NaN
# 13  COUNTRY_9891  BRAND_DB48   Nov            -11    NaN
# 14  COUNTRY_9891  BRAND_DB48   Dec            -10    NaN
# 15  COUNTRY_9891  BRAND_DB48   Jan             -9    NaN
# 16  COUNTRY_9891  BRAND_DB48   Feb             -8    NaN
# 17  COUNTRY_9891  BRAND_DB48   Mar             -7    NaN
# 18  COUNTRY_9891  BRAND_DB48   Apr             -6    NaN
# 19  COUNTRY_9891  BRAND_DB48   May             -5    NaN
# 20  COUNTRY_9891  BRAND_DB48   Jun             -4    NaN
# 21  COUNTRY_9891  BRAND_DB48   Jul             -3    NaN
# 22  COUNTRY_9891  BRAND_DB48   Aug             -2    NaN
# 23  COUNTRY_9891  BRAND_DB48   Sep             -1    NaN
# 24  COUNTRY_9891  BRAND_DB48   Oct              0    4.0
# 25  COUNTRY_9891  BRAND_DB48   Nov              1    4.0
# 26  COUNTRY_9891  BRAND_DB48   Dec              2    4.0
# 27  COUNTRY_9891  BRAND_DB48   Jan              3    4.0
# 28  COUNTRY_9891  BRAND_DB48   Feb              4    4.0
# 29  COUNTRY_9891  BRAND_DB48   Mar              5    4.0
# 30  COUNTRY_01A1  BRAND_0D48   Jul            -24    NaN
# 31  COUNTRY_01A1  BRAND_0D48   Aug            -23    NaN
# 32  COUNTRY_01A1  BRAND_0D48   Sep            -22    NaN
# 33  COUNTRY_01A1  BRAND_0D48   Oct            -21    NaN
# 34  COUNTRY_01A1  BRAND_0D48   Nov            -20    NaN
# 35  COUNTRY_01A1  BRAND_0D48   Dec            -19    NaN
# 36  COUNTRY_01A1  BRAND_0D48   Jan            -18    NaN
# 37  COUNTRY_01A1  BRAND_0D48   Feb            -17    NaN
# 38  COUNTRY_01A1  BRAND_0D48   Mar            -16    NaN
# 39  COUNTRY_01A1  BRAND_0D48   Apr            -15    NaN
# 40  COUNTRY_01A1  BRAND_0D48   May            -14    NaN
# 41  COUNTRY_01A1  BRAND_0D48   Jun            -13    NaN
# 42  COUNTRY_01A1  BRAND_0D48   Jul            -12    NaN
# 43  COUNTRY_01A1  BRAND_0D48   Aug            -11    NaN
# 44  COUNTRY_01A1  BRAND_0D48   Sep            -10    NaN
# 45  COUNTRY_01A1  BRAND_0D48   Oct             -9    NaN
# 46  COUNTRY_01A1  BRAND_0D48   Nov             -8    NaN
# 47  COUNTRY_01A1  BRAND_0D48   Dec             -7    NaN
# 48  COUNTRY_01A1  BRAND_0D48   Jan             -6    NaN
# 49  COUNTRY_01A1  BRAND_0D48   Feb             -5    NaN
#
#                    ther_area  hospital_rate main_package  biological  \
# 0   Cardiovascular_Metabolic       4.213704         PILL       False
# 1   Cardiovascular_Metabolic       4.213704         PILL       False
# 2   Cardiovascular_Metabolic       4.213704         PILL       False
# 3   Cardiovascular_Metabolic       4.213704         PILL       False
# 4   Cardiovascular_Metabolic       4.213704         PILL       False
# 5   Cardiovascular_Metabolic       4.213704         PILL       False
# 6   Cardiovascular_Metabolic       4.213704         PILL       False
# 7   Cardiovascular_Metabolic       4.213704         PILL       False
# 8   Cardiovascular_Metabolic       4.213704         PILL       False
# 9   Cardiovascular_Metabolic       4.213704         PILL       False
# 10  Cardiovascular_Metabolic       4.213704         PILL       False
# 11  Cardiovascular_Metabolic       4.213704         PILL       False
# 12  Cardiovascular_Metabolic       4.213704         PILL       False
# 13  Cardiovascular_Metabolic       4.213704         PILL       False
# 14  Cardiovascular_Metabolic       4.213704         PILL       False
# 15  Cardiovascular_Metabolic       4.213704         PILL       False
# 16  Cardiovascular_Metabolic       4.213704         PILL       False
# 17  Cardiovascular_Metabolic       4.213704         PILL       False
# 18  Cardiovascular_Metabolic       4.213704         PILL       False
# 19  Cardiovascular_Metabolic       4.213704         PILL       False
# 20  Cardiovascular_Metabolic       4.213704         PILL       False
# 21  Cardiovascular_Metabolic       4.213704         PILL       False
# 22  Cardiovascular_Metabolic       4.213704         PILL       False
# 23  Cardiovascular_Metabolic       4.213704         PILL       False
# 24  Cardiovascular_Metabolic       4.213704         PILL       False
# 25  Cardiovascular_Metabolic       4.213704         PILL       False
# 26  Cardiovascular_Metabolic       4.213704         PILL       False
# 27  Cardiovascular_Metabolic       4.213704         PILL       False
# 28  Cardiovascular_Metabolic       4.213704         PILL       False
# 29  Cardiovascular_Metabolic       4.213704         PILL       False
# 30           Anti-infectives      20.262344         PILL       False
# 31           Anti-infectives      20.262344         PILL       False
# 32           Anti-infectives      20.262344         PILL       False
# 33           Anti-infectives      20.262344         PILL       False
# 34           Anti-infectives      20.262344         PILL       False
# 35           Anti-infectives      20.262344         PILL       False
# 36           Anti-infectives      20.262344         PILL       False
# 37           Anti-infectives      20.262344         PILL       False
# 38           Anti-infectives      20.262344         PILL       False
# 39           Anti-infectives      20.262344         PILL       False
# 40           Anti-infectives      20.262344         PILL       False
# 41           Anti-infectives      20.262344         PILL       False
# 42           Anti-infectives      20.262344         PILL       False
# 43           Anti-infectives      20.262344         PILL       False
# 44           Anti-infectives      20.262344         PILL       False
# 45           Anti-infectives      20.262344         PILL       False
# 46           Anti-infectives      20.262344         PILL       False
# 47           Anti-infectives      20.262344         PILL       False
# 48           Anti-infectives      20.262344         PILL       False
# 49           Anti-infectives      20.262344         PILL       False
#
#     small_molecule
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# 5             True
# 6             True
# 7             True
# 8             True
# 9             True
# 10            True
# 11            True
# 12            True
# 13            True
# 14            True
# 15            True
# 16            True
# 17            True
# 18            True
# 19            True
# 20            True
# 21            True
# 22            True
# 23            True
# 24            True
# 25            True
# 26            True
# 27            True
# 28            True
# 29            True
# 30            True
# 31            True
# 32            True
# 33            True
# 34            True
# 35            True
# 36            True
# 37            True
# 38            True
# 39            True
# 40            True
# 41            True
# 42            True
# 43            True
# 44            True
# 45            True
# 46            True
# 47            True
# 48            True
# 49            True

# %%
output_df = X_test[["country", "brand_name", "months_postgx"]].copy()

# %%
output_df = pd.concat([output_df, pred_df], axis=1)

# %%
output_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8832 entries, 0 to 8831
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country        8832 non-null   object
#  1   brand_name     8832 non-null   object
#  2   months_postgx  8832 non-null   int64
#  3   volume         8832 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 276.1+ KB

# %%
output_df.head(50)
# Out:
#          country  brand_name  months_postgx         volume
# 0   COUNTRY_9891  BRAND_DB48            -24  227558.420591
# 1   COUNTRY_9891  BRAND_DB48            -23  217291.295814
# 2   COUNTRY_9891  BRAND_DB48            -22  243791.306709
# 3   COUNTRY_9891  BRAND_DB48            -21  223723.259185
# 4   COUNTRY_9891  BRAND_DB48            -20  230296.896790
# 5   COUNTRY_9891  BRAND_DB48            -19  229192.609588
# 6   COUNTRY_9891  BRAND_DB48            -18  234602.670330
# 7   COUNTRY_9891  BRAND_DB48            -17  218346.153932
# 8   COUNTRY_9891  BRAND_DB48            -16  235507.214757
# 9   COUNTRY_9891  BRAND_DB48            -15  252458.750032
# 10  COUNTRY_9891  BRAND_DB48            -14  228146.801601
# 11  COUNTRY_9891  BRAND_DB48            -13  255291.133420
# 12  COUNTRY_9891  BRAND_DB48            -12  223560.521693
# 13  COUNTRY_9891  BRAND_DB48            -11  216066.338548
# 14  COUNTRY_9891  BRAND_DB48            -10  242313.909548
# 15  COUNTRY_9891  BRAND_DB48             -9  223701.532450
# 16  COUNTRY_9891  BRAND_DB48             -8  218669.523998
# 17  COUNTRY_9891  BRAND_DB48             -7  218401.900991
# 18  COUNTRY_9891  BRAND_DB48             -6  221658.847722
# 19  COUNTRY_9891  BRAND_DB48             -5  211261.317821
# 20  COUNTRY_9891  BRAND_DB48             -4  222804.307083
# 21  COUNTRY_9891  BRAND_DB48             -3  229651.752881
# 22  COUNTRY_9891  BRAND_DB48             -2  218812.098753
# 23  COUNTRY_9891  BRAND_DB48             -1  239723.983788
# 24  COUNTRY_9891  BRAND_DB48              0   86244.506275
# 25  COUNTRY_9891  BRAND_DB48              1   73503.641543
# 26  COUNTRY_9891  BRAND_DB48              2   76688.780484
# 27  COUNTRY_9891  BRAND_DB48              3   67212.655822
# 28  COUNTRY_9891  BRAND_DB48              4   66361.773161
# 29  COUNTRY_9891  BRAND_DB48              5   69226.803350
# 30  COUNTRY_01A1  BRAND_0D48            -24   58130.338207
# 31  COUNTRY_01A1  BRAND_0D48            -23   54512.889545
# 32  COUNTRY_01A1  BRAND_0D48            -22   56235.815773
# 33  COUNTRY_01A1  BRAND_0D48            -21   50461.290403
# 34  COUNTRY_01A1  BRAND_0D48            -20   51969.279038
# 35  COUNTRY_01A1  BRAND_0D48            -19   58551.260600
# 36  COUNTRY_01A1  BRAND_0D48            -18   56398.704949
# 37  COUNTRY_01A1  BRAND_0D48            -17   54793.418188
# 38  COUNTRY_01A1  BRAND_0D48            -16   55926.509269
# 39  COUNTRY_01A1  BRAND_0D48            -15   57826.944959
# 40  COUNTRY_01A1  BRAND_0D48            -14   50950.589513
# 41  COUNTRY_01A1  BRAND_0D48            -13   57879.525936
# 42  COUNTRY_01A1  BRAND_0D48            -12   57109.065453
# 43  COUNTRY_01A1  BRAND_0D48            -11   54205.578753
# 44  COUNTRY_01A1  BRAND_0D48            -10   55895.021691
# 45  COUNTRY_01A1  BRAND_0D48             -9   50456.389888
# 46  COUNTRY_01A1  BRAND_0D48             -8   49345.421793
# 47  COUNTRY_01A1  BRAND_0D48             -7   55794.585364
# 48  COUNTRY_01A1  BRAND_0D48             -6   53286.997691
# 49  COUNTRY_01A1  BRAND_0D48             -5   53015.496385

# %%
# to filter down rows to post generic entry
output_df = output_df[output_df["months_postgx"].between(0, 23)]
# Out:
#          country  brand_name  months_postgx         volume
# 0   COUNTRY_0024  BRAND_79B0              0   10307.284895
# 1   COUNTRY_0024  BRAND_79B0              1    7841.610568
# 2   COUNTRY_0024  BRAND_79B0              2    6776.532333
# 3   COUNTRY_0024  BRAND_79B0              3    4105.890352
# 4   COUNTRY_0024  BRAND_79B0              4    3795.333506
# 5   COUNTRY_0024  BRAND_79B0              5    3780.207235
# 6   COUNTRY_0024  BRAND_8164              0    9203.649306
# 7   COUNTRY_0024  BRAND_8164              1    7843.998055
# 8   COUNTRY_0024  BRAND_8164              2    8183.902624
# 9   COUNTRY_0024  BRAND_8164              3    7172.650639
# 10  COUNTRY_0024  BRAND_8164              4    7081.848037
# 11  COUNTRY_0024  BRAND_8164              5    7387.591953
# 12  COUNTRY_01A1  BRAND_0D48              0   32658.769100
# 13  COUNTRY_01A1  BRAND_0D48              1   27335.319975
# 14  COUNTRY_01A1  BRAND_0D48              2   22201.567521
# 15  COUNTRY_01A1  BRAND_0D48              3   19026.341762
# 16  COUNTRY_01A1  BRAND_0D48              4   18794.622635
# 17  COUNTRY_01A1  BRAND_0D48              5   22195.602615
# 18  COUNTRY_01A1  BRAND_9EFF              0    3002.626379
# 19  COUNTRY_01A1  BRAND_9EFF              1    2698.135130
# 20  COUNTRY_01A1  BRAND_9EFF              2    2584.129438
# 21  COUNTRY_01A1  BRAND_9EFF              3    2580.044611
# 22  COUNTRY_01A1  BRAND_9EFF              4    2303.933537
# 23  COUNTRY_01A1  BRAND_9EFF              5    2294.751229
# 24  COUNTRY_0309  BRAND_09BA              0  420349.622458
# 25  COUNTRY_0309  BRAND_09BA              1  377722.680030
# 26  COUNTRY_0309  BRAND_09BA              2  326418.907450
# 27  COUNTRY_0309  BRAND_09BA              3  275922.329527
# 28  COUNTRY_0309  BRAND_09BA              4  255052.417968
# 29  COUNTRY_0309  BRAND_09BA              5  254035.908626

# %%
# index put to false so that it doesn't add an index column at the front
output_df.to_csv("Poisson_Regression_Output.csv", index=False)
